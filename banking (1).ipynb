# %%
 import pymongo
client=pymongo.MongoClient("mongodb://localhost:27017")


database=client["banking"]
collection=database["customer details"]

print("Welcome to the FINO HUB")
while True:
    print("1: for Open Account:")
    print("2: for Deposit:")
    print("3: for Withdraw Amount:")
    print("4: for Check Balance:")
    print("5: Update Account Details:'Phone','Address':")
    print("6: To Close Account:")
    print("0: for Exit")

    choice=int(input("Enter the choice:"))

    if(choice==1):
        while True:
            name=input("Enter the Name :").upper()
            if(name.isalpha()):
                 break
            else:
                 print("Enter the Valid Name  :")
        while True:
             phone=input("Enter the Phone number:")
             if((len(phone))==10 and phone.isdigit()):  
                 break
             else:
                  print("Enter valid Number:")
        balance=10000
        House_number=input("Enter the House Number:")
        #Address[House_number]=House_number
        while True:
            Country=input("Enter the Country: ")
            State=input("Enter the State:")
            City=input("Enter the City:")
            if(Country.isalpha() and State.isalpha() and City.isalpha()):
                break
            else:
                print("Enter the Valid ")
            
        while True:        
            pin=input("Enter the PIN: ")
            if(pin.isdigit() and len(pin)==6):
            #Address["Pin"]=Pin
                break
            else:
                 print("Enter the Valid Pin:")
        

        print("Enter the DOB:")
        date_of_birth={
        "month":int(input("enter the Month")),
        "date":int(input("enter the Date")),
        "year":int(input("enter the Year"))
        }
        while True:
            aaddhar_no=input("Enter the Aaddhar No. : ")
            if(aaddhar_no.isdigit() and len(aaddhar_no)==12):
                break
            else:
                print("Enter valid Aaddhar")
        
        print("CONGRATULATIONS")
        print("YOUR ACCOUNT CREATED SUCCESFULLY")

        account_no="9999"+phone[4:]+aaddhar_no[4:]
        ifsc_no="IFSC"+pin[3:]+phone[-3:]    
       
        print("Here is your ACCOUNT NUMBER=",account_no)
        print("IFSC CODE=",ifsc_no)
        print("---------------------------------------------------")

        print("Deposit the Minimum Balance of Rupees 10,000")
        minimum_balance=10000
        #minimum_balance.append(balance)
        print("Press2: for deposit=")

        print("---------------------------------------------------")

        account={
        "account_no": account_no,
        "name": name,
        "phone": phone,
        "aadhaar": aaddhar_no,
        "address": {
        "house": House_number,
        "city": City,
        "state": State,
        "country": Country,
        "pin": pin
                   },
        "dob": date_of_birth,
            "ifsc": ifsc_no,
            "balance": balance
            }
        collection.insert_one(account)
        
        print("Account details=",account)
        
       # while True:
            #minimum_balance=float(input("Deposit the Minimum Balance = "))
            #if( minimum_balance>=10000):
                #balance=balance+minimum_balance
                #break
            #else:
                #print("Deposit Amount should be >=10000")
    elif choice == 2:
        acc_no = input("Enter your account number: ")
        user = collection.find_one({"account_no": acc_no})
        if user:
            money = float(input("Enter the amount you want to add: "))
            new_balance = user["balance"] + money
            collection.update_one({"account_no": acc_no}, {"$set": {"balance": new_balance}})
            print(f"✅ Amount Deposited. New Balance: ₹{new_balance}")
        else:
            print("❌ Account not found.")
    elif(choice==3):
        while True:
            acc_no = input("Enter your account number: ")
            user = collection.find_one({"account_no": acc_no})
            money=float(input("Enter the amount you want to Withdraw="))
            current_balance = user["balance"]
            if money <= current_balance:
               new_balance = current_balance - money
               collection.update_one({"account_no": acc_no}, {"$set": {"balance": new_balance}})
               print(f"✅ Amount Withdrawn. Remaining Balance: ₹{new_balance}")
               break
            else:
                print("Overdraft is not allowed yet")
        print("Amoount Deducted Successfully")
    elif(choice==4):
        acc_no = input("Enter your account number: ")
        user = collection.find_one({"account_no": acc_no})
        if user:
               print(f"✅ Current Balance: ₹{user['balance']}")
        else:
             print("❌ Account not found.")
    elif(choice==5):
        acc_no=input("Enter the Account Number to update details:")
        if(acc_no==account_no):
            collection.find_one({"account_no":acc_no})
        else:
            print("Account not found")
            #if user:
        print("What you want to update:Phone Number or Address")
        print("1: for Update Phone  Number:")
        print("2: for Update Address:")
        update_choice=int(input("Enter the choice 1/2 "))
        if(update_choice==1):
            new_phone=input("Enter the new phone number")
            if(len(new_phone)==10):
                collection.update_one(
                      {"account_no": acc_no},
                      {"$set": {"phone": new_phone}}
                       )
                    
            else:
                 print("Enter the Valid Number")
        elif(update_choice==2):
            house_no=input("Enter the House Number")
            country=input("Enter the Country: ")
            State=input("Enter the State:")
            City=input("Enter the City:")
            pin=input("Enter the PIN: ")
            if(pin.isdigit() and len(pin)==6):
                pass
            else:
                print("Enter the Valid Pin:")
            new_address = {
                    "house_number": house_no,
                    "city": city,
                    "state": state,
                    "country": country,
                    "pin": pin
                }
            collection.update_one(
                    {"account_no": acc_no},
                    {"$set": {"address": new_address}}
                )
            print("✅ Address updated successfully.")
            
    elif(choice==6):
        acc_no=input("Enter the Account no. :")
        confirm=input("Do you want to close your Account  (yes/no):  ").lower()
        if confirm=="yes":
            collection.delete_one({"account_no":account_no})
            print("Account Deleted Successfully")
        else:
            print("Account closure cancelled")
            print("Connect to the branch if have any other Query")
    elif(choice==0):
        print("Thanks for Choose us")
        print("IF you have any other QUERY connect with nearest Branch")
        break
    else:
        print("Thanks for Visiting")
 
    #if (i==0):
       # break
print("Thanks for Visiting")

0
# Out:
# Welcome to the FINO HUB
# 1: for Open Account:
# 2: for Deposit:
# 3: for Withdraw Amount:
# 4: for Check Balance:
# 5: Update Account Details:'Phone','Address':
# 6: To Close Account:
# 0: for Exit
# Enter the choice: 0
# Thanks for Choose us
# IF you have any other QUERY connect with nearest Branch
# Thanks for Visiting
